# %% [markdown]
# <a href="https://colab.research.google.com/github/HQDQVINH1/DANH_GIA_DU_AN/blob/main/Copy_Folder_Google_Drive_to_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Copy Folder Google Drive to Google Drive - 1TouchPro

# %%
#@title Input
from ipywidgets import widgets

dest_text = widgets.Text(description="Your drive", placeholder='Nhập đường link folder Google Drive của bạn')
source_text = widgets.Text(description="Shared drive", placeholder='Nhập đường link folder Google Drive shared')
from_page_text = widgets.Text(description="Từ trang", value="0")
to_page_text = widgets.Text(description="Đến trang", value="0")
max_download_size_text = widgets.Text(description="Tổng dung lượng tối đa(GB)", value="700")
exclude_str_text = widgets.Text(description="Bỏ file, folder có chứa nội dung", value="")

display(dest_text)
display(source_text)
display(from_page_text)
display(to_page_text)
display(max_download_size_text)
display(exclude_str_text)
# Out:
# Text(value='', description='Your drive', placeholder='Nhập đường link folder Google Drive của bạn')
# Text(value='', description='Shared drive', placeholder='Nhập đường link folder Google Drive shared')
# Text(value='0', description='Từ trang')
# Text(value='0', description='Đến trang')
# Text(value='700', description='Tổng dung lượng tối đa(GB)')
# Text(value='', description='Bỏ file, folder có chứa nội dung')

# %%
#@title Run
import os
import time
import re
import sys
from googleapiclient.discovery import build
from google.colab import auth
from google.colab import drive

class DownloadFromDrive:
    def __init__(self):
        self._total_size = 0
        self._limit_size = 0
        self.excluded_strings = []

    def get_user_credential(self):
        auth.authenticate_user()
        drive_service = build('drive', 'v3')
        return drive_service

    def get_childs_from_folder(self, drive_service, folder_id, from_page, to_page):
        files = []
        page_token = None
        query = f"'{folder_id}' in parents and trashed = false"
        if self.excluded_strings and len(self.excluded_strings) > 0:
            not_contains_query = " and ".join([f"not name contains '{ext}'" for ext in self.excluded_strings])
            query += f" and ({not_contains_query})"

        pages = 0
        while True:
            try:
                pages += 1
                response = drive_service.files().list(q=query,
                                        orderBy='name, createdTime',
                                        fields='files(id, name, mimeType, size), nextPageToken',
                                        pageToken=page_token,
                                        supportsAllDrives=True,
                                        includeItemsFromAllDrives=True).execute()

                if (from_page < pages <= to_page) or to_page == 0:
                    files.extend(response.get('files', []))

                page_token = response.get('nextPageToken', None)
                if page_token is None or  (pages >= to_page > 0):
                    break
            except Exception as e:
                print(f"An error occurred: {str(e)}")
                page_token = None

        print(f"Total files: {len(files)}")
        return files

    def copy_file(self, drive_service, dest_folder_id, source_file):
        if source_file['mimeType'] != 'application/vnd.google-apps.folder':
            body_file_inf = {'parents': [dest_folder_id]}

            if not self.check_if_exists(drive_service, dest_folder_id, source_file['name']):
                try:
                    start_time = time.time()
                    request_copy = drive_service.files().copy(body=body_file_inf, fileId=source_file['id'],
                                                              supportsAllDrives=True).execute()
                    end_time = time.time()

                    fileSize = int(source_file.get('size', 0))
                    size_mb = fileSize / (1024 * 1024)
                    self._total_size += size_mb
                    speed_mb = size_mb / (end_time - start_time)
                    print(f"[{source_file['name']}] copied. Size {size_mb:0.2f} MB. Speed {speed_mb:0.2f} MB/s")


                    if self._total_size >= (self._limit_size * 1024):
                        self.on_total_size_exceeded(f"Total size exceeds {self._limit_size} GB. Ending the program.")
                except Exception as e:
                    print("An error occurred: ", e)
            else:
                print(f"[{source_file['name']}] exists.")
        else:

            source_files = self.get_childs_from_folder(drive_service, source_file['id'], 0, 0)
            if source_files and len(source_files) > 0:
                print(f"Copy at Folder {source_file['name']} Starting")
                sub_folder_id = self.create_folder(drive_service, dest_folder_id, source_file['name'])
                self.copy_multiple_files(drive_service, sub_folder_id, source_files)
                print(f"Copy at Folder {source_file['name']} Ending")


    def create_folder(self, drive_service, dest_folder_id, sub_folder_name):
        sub_folder_inf = {'name': sub_folder_name, 'mimeType': 'application/vnd.google-apps.folder', 'parents': [dest_folder_id]}

        exist_folder_id = self.check_if_exists(drive_service, dest_folder_id, sub_folder_name)
        if not exist_folder_id:
            try:
                folder = drive_service.files().create(body=sub_folder_inf, fields='id').execute()
                return folder['id']
            except Exception as e:
                print("An error occurred: ", e)
        return exist_folder_id


    def check_if_exists(self, drive_service, dest_folder_id, name):
        try:
            processed_name = name.replace("'", "\\'")

            results = drive_service.files().list(q=f"'{dest_folder_id}' in parents and name contains '{processed_name}' and trashed=false",
                                                fields='files(id)').execute()

            if 'files' in results and len(results['files']) > 0:
                return results['files'][0]['id']
        except Exception as e:
            print("An error occurred: ", e)

        return ""


    def copy_multiple_files(self, drive_service, dest_folder_id, source_files):
        for source_file in source_files:
            self.copy_file(drive_service, dest_folder_id, source_file)

    def extract_folder_id_from_url(self, url):
        pattern = r'[-\w]{25,}'
        match = re.search(pattern, url)
        if match:
            return match.group(0)
        else:
            return None

    def on_total_size_exceeded(self, message):
        print(message)
        sys.exit()

    def copy_drive_to_drive(self, destDriveLink, sourceDriveLink, from_page, to_page):
        service = self.get_user_credential()

        start_time = time.time()
        dest_folder_id = self.extract_folder_id_from_url(destDriveLink)
        source_folder_id = self.extract_folder_id_from_url(sourceDriveLink)
        source_folder = service.files().get(fileId=source_folder_id, supportsAllDrives=True).execute()
        new_dest_folder_id = self.create_folder(service, dest_folder_id, source_folder['name'])

        source_files = self.get_childs_from_folder(service, source_folder_id, from_page, to_page)
        self.copy_multiple_files(service, new_dest_folder_id, source_files)
        end_time = time.time()

        size_gb = self._total_size / 1024
        speed_mb = self._total_size / (end_time - start_time)

        print(f"Done. Total Size {size_gb:0.2f} GB. Total Time {int(end_time - start_time)} s. SpeedMB {speed_mb:0.2f} MB/s")


# Main
destDriveLink = dest_text.value
sourceDriveLink = source_text.value
fromPage = int(from_page_text.value)
toPage = int(to_page_text.value)

downloader = DownloadFromDrive()
downloader._limit_size = float(max_download_size_text.value);
downloader.excluded_strings = [ext.strip() for ext in exclude_str_text.value.split(",") if ext.strip()]
downloader.copy_drive_to_drive(destDriveLink, sourceDriveLink, fromPage, toPage)
# Out:
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# Total files: 2
# Total files: 55
# Copy at Folder 081125 Starting
# [C1700.MP4] copied. Size 170.49 MB. Speed 115.39 MB/s
# [C1700M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1701.MP4] copied. Size 56.10 MB. Speed 41.64 MB/s
# [C1701M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1702.MP4] copied. Size 153.31 MB. Speed 106.35 MB/s
# [C1702M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1703.MP4] copied. Size 129.73 MB. Speed 86.55 MB/s
# [C1703M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1704.MP4] copied. Size 49.02 MB. Speed 31.66 MB/s
# [C1704M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1705.MP4] copied. Size 259.76 MB. Speed 197.50 MB/s
# [C1705M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1706.MP4] copied. Size 286.89 MB. Speed 206.11 MB/s
# [C1706M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1707.MP4] copied. Size 317.63 MB. Speed 234.08 MB/s
# [C1707M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1708.MP4] copied. Size 23.37 MB. Speed 16.50 MB/s
# [C1708M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1709.MP4] copied. Size 168.99 MB. Speed 126.57 MB/s
# [C1709M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1710.MP4] copied. Size 1780.38 MB. Speed 1248.74 MB/s
# [C1710M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1711.MP4] copied. Size 157.10 MB. Speed 119.51 MB/s
# [C1711M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1712.MP4] copied. Size 4205.85 MB. Speed 2678.56 MB/s
# [C1712M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1713.MP4] copied. Size 65.09 MB. Speed 49.02 MB/s
# [C1713M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1714.MP4] copied. Size 109.85 MB. Speed 72.71 MB/s
# [C1714M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1715.MP4] copied. Size 504.45 MB. Speed 321.42 MB/s
# [C1715M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1716.MP4] copied. Size 279.83 MB. Speed 206.24 MB/s
# [C1716M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1717.MP4] copied. Size 501.58 MB. Speed 323.43 MB/s
# [C1717M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1718.MP4] copied. Size 132.45 MB. Speed 93.29 MB/s
# [C1718M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1719.MP4] copied. Size 612.02 MB. Speed 387.92 MB/s
# [C1719M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1720.MP4] copied. Size 119.86 MB. Speed 91.67 MB/s
# [C1720M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1721.MP4] copied. Size 158.04 MB. Speed 131.71 MB/s
# [C1721M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1722.MP4] copied. Size 69.69 MB. Speed 50.85 MB/s
# [C1722M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1723.MP4] copied. Size 4486.76 MB. Speed 2965.23 MB/s
# [C1723M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1724.MP4] copied. Size 1787.37 MB. Speed 1123.57 MB/s
# [C1724M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1725.MP4] copied. Size 795.51 MB. Speed 445.59 MB/s
# [C1725M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1726.MP4] copied. Size 856.06 MB. Speed 654.70 MB/s
# [C1726M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1727.MP4] copied. Size 1899.39 MB. Speed 1322.19 MB/s
# Copy at Folder 081125 Ending
# Total files: 90
# Copy at Folder 101125 Starting
# [C1728.MP4] copied. Size 61.07 MB. Speed 36.84 MB/s
# [C1728M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1729.MP4] copied. Size 84.28 MB. Speed 61.61 MB/s
# [C1729M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1730.MP4] copied. Size 139.60 MB. Speed 115.67 MB/s
# [C1730M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1731.MP4] copied. Size 97.39 MB. Speed 61.68 MB/s
# [C1731M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1732.MP4] copied. Size 84.45 MB. Speed 62.54 MB/s
# [C1732M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1733.MP4] copied. Size 36.29 MB. Speed 25.72 MB/s
# [C1733M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1734.MP4] copied. Size 31.48 MB. Speed 24.38 MB/s
# [C1734M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1735.MP4] copied. Size 40.72 MB. Speed 34.13 MB/s
# [C1735M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1736.MP4] copied. Size 29.97 MB. Speed 16.45 MB/s
# [C1736M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1737.MP4] copied. Size 42.47 MB. Speed 26.21 MB/s
# [C1737M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1738.MP4] copied. Size 67.95 MB. Speed 51.75 MB/s
# [C1738M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1739.MP4] copied. Size 51.67 MB. Speed 37.66 MB/s
# [C1739M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1740.MP4] copied. Size 42.50 MB. Speed 32.39 MB/s
# [C1740M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1741.MP4] copied. Size 64.08 MB. Speed 49.60 MB/s
# [C1741M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1742.MP4] copied. Size 56.27 MB. Speed 35.75 MB/s
# [C1742M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1743.MP4] copied. Size 60.78 MB. Speed 50.14 MB/s
# [C1743M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1744.MP4] copied. Size 64.34 MB. Speed 49.51 MB/s
# [C1744M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1745.MP4] copied. Size 92.76 MB. Speed 63.46 MB/s
# [C1745M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1746.MP4] copied. Size 54.36 MB. Speed 34.94 MB/s
# [C1746M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1747.MP4] copied. Size 58.08 MB. Speed 46.99 MB/s
# [C1747M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1748.MP4] copied. Size 122.80 MB. Speed 90.29 MB/s
# [C1748M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1749.MP4] copied. Size 83.86 MB. Speed 69.65 MB/s
# [C1749M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1750.MP4] copied. Size 98.45 MB. Speed 61.97 MB/s
# [C1750M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1751.MP4] copied. Size 48.78 MB. Speed 39.66 MB/s
# [C1751M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1752.MP4] copied. Size 83.90 MB. Speed 60.79 MB/s
# [C1752M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1753.MP4] copied. Size 36.15 MB. Speed 27.68 MB/s
# [C1753M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1754.MP4] copied. Size 97.65 MB. Speed 78.56 MB/s
# [C1754M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1755.MP4] copied. Size 94.10 MB. Speed 59.95 MB/s
# [C1755M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1756.MP4] copied. Size 44.55 MB. Speed 37.82 MB/s
# [C1756M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1757.MP4] copied. Size 127.79 MB. Speed 94.92 MB/s
# [C1757M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1758.MP4] copied. Size 104.43 MB. Speed 87.40 MB/s
# [C1758M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1759.MP4] copied. Size 52.52 MB. Speed 38.36 MB/s
# [C1759M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1760.MP4] copied. Size 109.88 MB. Speed 53.72 MB/s
# [C1760M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1761.MP4] copied. Size 45.75 MB. Speed 33.35 MB/s
# [C1761M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1762.MP4] copied. Size 48.55 MB. Speed 38.60 MB/s
# [C1762M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1763.MP4] copied. Size 43.06 MB. Speed 36.19 MB/s
# [C1763M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1764.MP4] copied. Size 52.26 MB. Speed 43.79 MB/s
# [C1764M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1765.MP4] copied. Size 86.22 MB. Speed 65.24 MB/s
# [C1765M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1766.MP4] copied. Size 42.86 MB. Speed 35.91 MB/s
# [C1766M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1767.MP4] copied. Size 94.13 MB. Speed 78.26 MB/s
# [C1767M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1768.MP4] copied. Size 74.10 MB. Speed 53.69 MB/s
# [C1768M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1769.MP4] copied. Size 33.25 MB. Speed 26.85 MB/s
# [C1769M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1770.MP4] copied. Size 32.90 MB. Speed 17.07 MB/s
# [C1770M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1771.MP4] copied. Size 42.21 MB. Speed 29.66 MB/s
# [C1771M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# [C1772.MP4] copied. Size 51.72 MB. Speed 40.54 MB/s
# [C1772M01.XML] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 101125 Ending
# Done. Total Size 22.61 GB. Total Time 233 s. SpeedMB 99.00 MB/s
